# %%
import xml.etree.ElementTree as ET
import networkx as nx
import os
from math import sqrt
import matplotlib.pyplot as plt
from collections import deque, Counter

# Function to parse XPDL and order transitions correctly
def parse_xpdl(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    ns = {'xpdl': 'http://www.wfmc.org/2009/XPDL2.2'}
    
    # Lists
    pools = []
    lanes = []
    activities = []
    transitions = []  # Now using a list with manual duplicate check
    associations = []
    message_flows = []
    activity_id_to_name = {}  # Mapping from activity ID to name
    id_to_activity = {}  # Store activity details for reference
    
    # Parse Pools
    for pool in root.findall('.//xpdl:Pool', ns):
        pool_name = pool.get('Name')
        if pool_name:
            pools.append({'name': pool_name})
    
    # Parse Lanes
    for lane in root.findall('.//xpdl:Lane', ns):
        lane_name = lane.get('Name')
        if lane_name:
            lanes.append({'name': lane_name})
    
    # Parse Activities
    for activity in root.findall('.//xpdl:Activity', ns):
        activity_id = activity.get('Id')
        activity_name = activity.get('Name')
        event = activity.find('.//xpdl:Event', ns)
        route = activity.find('.//xpdl:Route', ns)
        gateway_type = route.get('GatewayType') if route is not None else 'None'
        is_start_event = False
        is_end_event = False
        
        if event is not None:
            if event.find('xpdl:StartEvent', ns) is not None:
                activity_name = 'StartEvent'
                is_start_event = True
            elif event.find('xpdl:EndEvent', ns) is not None:
                activity_name = 'EndEvent'
                is_end_event = True

        if activity_id:
            activity_detail = {
                'id': activity_id,
                'name': activity_name,
                'type': gateway_type,
                'is_start_event': is_start_event,
                'is_end_event': is_end_event,
                'from': [],
                'to': [],
                'data_objects': []  # Initialize an empty list for attached data objects
            }
            id_to_activity[activity_id] = activity_detail
            activity_id_to_name[activity_id] = activity_name if activity_name else activity_id

    # Parse DataObjects and assign them to the corresponding Activity
    for data_object in root.findall('.//xpdl:DataObject', ns):
        data_id = data_object.get('Id')
        data_name = data_object.get('Name')
        if data_id and data_name:
            for activity in id_to_activity.values():
                activity['data_objects'].append({'id': data_id, 'name': data_name, 'type': 'DataObject'})

    # Parse DataStores and assign them to the corresponding Activity
    for data_store in root.findall('.//xpdl:DataStore', ns):
        data_id = data_store.get('Id')
        data_name = data_store.get('Name')
        if data_id and data_name:
            for activity in id_to_activity.values():
                activity['data_objects'].append({'id': data_id, 'name': data_name, 'type': 'DataStore'})

            
    # Parse Transitions and create a transition map
    transition_map = {}  # Map each source to its target(s)
    reverse_transition_map = {}  # Map each target to its source(s)
    for transition in root.findall('.//xpdl:Transition', ns):
        source = transition.get('From')
        target = transition.get('To')
        if source and target:
            if source not in transition_map:
                transition_map[source] = []
            transition_map[source].append(target)

            if target not in reverse_transition_map:
                reverse_transition_map[target] = []
            reverse_transition_map[target].append(source)

            # Update `from` and `to` references
            if source in id_to_activity:
                id_to_activity[source]['to'].append(target)
            if target in id_to_activity:
                id_to_activity[target]['from'].append(source)
           
    # Add Associations to Transitions
    for association in root.findall('.//xpdl:Association', ns):
        source = association.get('Source')
        target = association.get('Target')
        name = "data"
        if source in id_to_activity:
            for data_object in id_to_activity[source]["data_objects"]:
                if data_object["id"] == target:
                    name = data_object["name"]
        else:
            print(f"Warning: Association source {source} not found in id_to_activity.")
        if source and target:
            associations.append({'from': activity_id_to_name.get(source, source), 'to': name})

    # Add Message Flows to Transitions
    for message_flow in root.findall('.//xpdl:MessageFlow', ns):
        source = message_flow.get('Source')
        target = message_flow.get('Target')
        name = "data"
        if source in id_to_activity:
            for data_object in id_to_activity[source]["data_objects"]:
                if data_object["id"] == target:
                    name = data_object["name"]
        else:
            print(f"Warning: MessageFlow source {source} not found in id_to_activity.")
        if source and target:
            message_flows.append({'from': activity_id_to_name.get(source, source), 'to': name})

                
    # Find the StartEvent node
    start_node = next((act for act in id_to_activity.values() if act['is_start_event']), None)
    if not start_node:
        raise ValueError("No StartEvent found in the XPDL.")

    # Track visited nodes
    visited = set()
    ordered_transitions = []  # Store transitions in order

    # Traverse the transitions in correct order using BFS
    queue = deque([start_node['id']])
    while queue:
        current_id = queue.popleft()
        if current_id in visited:
            continue
        visited.add(current_id)

        if current_id in transition_map:
            for target_id in transition_map[current_id]:
                transition_entry = {
                    'from': activity_id_to_name.get(current_id, current_id),
                    'to': activity_id_to_name.get(target_id, target_id)
                }

                # **Manually check for duplicates before adding**
                if transition_entry not in ordered_transitions:
                    ordered_transitions.append(transition_entry)
                queue.append(target_id)

    # Detect missing transitions
    missing_transitions = []
    for activity in id_to_activity.keys():
        if activity not in visited:
            missing_transitions.append(activity)

    # **Step 1: Reconstruct missing transitions using XPDL `from` and `to`**
    if missing_transitions:
        print("\n⚠️ Missing transitions detected! Attempting to reconstruct...")
        for missing_id in missing_transitions:
            missing_activity = id_to_activity[missing_id]
            print(f"  - {missing_activity['name']} ({missing_id}) is missing connections.")

            # Find the correct `from` node from the original XPDL transition list
            if missing_id in reverse_transition_map:
                correct_from = reverse_transition_map[missing_id][0]  # Take the first known connection
                correct_from_name = activity_id_to_name.get(correct_from, correct_from)

                transition_entry = {
                    'from': correct_from_name,
                    'to': activity_id_to_name.get(missing_id, missing_id)
                }
                if transition_entry not in ordered_transitions:  # Prevent duplicates
                    ordered_transitions.append(transition_entry)
                    print(f"  ✅ Reconstructed missing transition: {correct_from_name} → {missing_activity['name']}")

            if missing_id in transition_map:
                correct_to = transition_map[missing_id][0]  # Take the first known connection
                correct_to_name = activity_id_to_name.get(correct_to, correct_to)

                transition_entry = {
                    'from': activity_id_to_name.get(missing_id, missing_id),
                    'to': correct_to_name
                }
                if transition_entry not in ordered_transitions:  # Prevent duplicates
                    ordered_transitions.append(transition_entry)
                    print(f"  ✅ Reconstructed missing transition: {missing_activity['name']} → {correct_to_name}")

    # **Step 3: Append Associations & Message Flows in Order**
    ordered_transitions.extend(associations)
    ordered_transitions.extend(message_flows)
                    
    print("Final Transitions:", file_path, ordered_transitions)

    return {
        'pools': pools,
        'lanes': lanes,
        'activities': list(id_to_activity.values()),
        'transitions': ordered_transitions,  # Use ordered transitions
        'associations': associations,
        'message_flows': message_flows
    }


def convert_to_interstructural_with_order(parsed_data):
    """
    Convert parsed XPDL data into a graph preserving the original process flow.
    Activities and transitions are added in the correct order.
    """
    G = nx.DiGraph()

    # Map activity IDs to their details for quick access
    activity_map = {activity['id']: activity for activity in parsed_data['activities']}

    # Step 1: Add all activities first but connect them through transitions
    print("parsed_data['transitions']", parsed_data['transitions'])
    for transition in parsed_data['transitions']:
        source_id = transition['from']
        target_id = transition['to']

        # Ensure the source and target activities exist
        source_activity = activity_map.get(source_id, {'name': source_id, 'type': 'Unknown'})
        target_activity = activity_map.get(target_id, {'name': target_id, 'type': 'Unknown'})
        print("source_id->", source_id, "|||", source_activity)
        print("target_id->", target_id, "|||", target_activity)

        if not source_activity['name']:
            source_activity['name'] = str(source_activity["type"]) + "_" + source_activity["id"]
            
        if not target_activity['name']:
            target_activity['name'] = str(target_activity["type"]) + "_" + target_activity["id"]
        
        # Add source activity if not already added
        if not G.has_node(source_activity['name']):
            G.add_node(source_activity['name'], label=source_activity['name'], type=source_activity.get('type', 'Activity'))
            
        # Add transition node
        transition_node = f"Transition_{source_activity['name']}_to_{target_activity['name']}"
        G.add_node(transition_node, label=transition_node, type="Transition")    
        
        # Add target activity if not already added
        if not G.has_node(target_activity['name']):
            G.add_node(target_activity['name'], label=target_activity['name'], type=target_activity.get('type', 'Activity'))

        # Connect source -> transition -> target
        G.add_edge(source_activity['name'], transition_node)  # Source to Transition
        G.add_edge(transition_node, target_activity['name'])  # Transition to Target

    return G

def text_to_vector(text):
    """
    Converts a string into a frequency vector.
    """
    words = text.lower().split()
    return Counter(words)

def cosine_similarity(text1, text2):
    """
    Calculates cosine similarity between two text strings.
    """
    vector1 = text_to_vector(text1)
    vector2 = text_to_vector(text2)
    # print(vector1, vector2)

    intersection = set(vector1.keys()) & set(vector2.keys())
    dot_product = sum([vector1[word] * vector2[word] for word in intersection])

    magnitude1 = sqrt(sum([count ** 2 for count in vector1.values()]))
    magnitude2 = sqrt(sum([count ** 2 for count in vector2.values()]))

    if not magnitude1 or not magnitude2:
        return 0.0

    return dot_product / (magnitude1 * magnitude2)

def calculate_semantic_similarity(target_node, other_node, component):
    """
    Calculates semantic similarity between two nodes using cosine similarity.
    Missing sub-components are skipped, and the result is normalized by the total weight.
    """

    # Adjusted weights with 'label' and normalized to sum to 1
    sub_components_weights = {
        'pools': (['label'], [1.0]),
        'lanes': (['label'], [1.0]),
        'activities': (['label', 'type'], [0.5, 0.5]),
        'data_objects': (['label', 'type'], [0.5, 0.5]),
        'transitions': (['type'], [1.0]),  # Only check 'type' for transitions
        'associations': (['label'], [1.0]),
        'message_flows': (['label'], [1.0])
    }

    if component not in sub_components_weights:
        return 0  # If the component type doesn't match, return 0 similarity

    sub_components, weights = sub_components_weights[component]
    similarities = []
    existing_weights = 0  # To normalize only the used weights

    # Calculate weighted cosine similarity for each sub-component
    for sub_component, weight in zip(sub_components, weights):
        target_value = target_node.get(sub_component, None)
        other_value = other_node.get(sub_component, None)

        # Skip if either value is missing
        if target_value is None or other_value is None:
            continue

        # Apply cosine similarity for textual comparison
        similarity = cosine_similarity(str(target_value), str(other_value))
        similarities.append(weight * similarity)
        existing_weights += weight  # Only sum up existing weights

    # If no valid components were compared, return 0
    if existing_weights == 0:
        return 0

    # Normalize by the sum of existing weights
    return sum(similarities) / existing_weights


def calculate_structural_similarity(target_node_data, other_node_data):
    """
    Menghitung kemiripan struktural antara dua node menggunakan Graph Edit Distance (GED).
    - Cost Insert, Delete, Substitusi = 1
    - Jika tipe node berbeda → Cost 2 (karena harus delete + insert)
    - Jika target node missing → Cost 1 (karena hanya perlu insert)
    - Jika tipe sama tapi kontennya beda → Cost 1 (karena hanya perlu subtitusi)
    
    Hasil Similarity:
    - Cost 0 → Similarity = 1.0 (100%)
    - Cost 1 → Similarity = 0.5 (50%)
    - Cost 2 → Similarity = 0.0 (0%)
    """
    
    cost_insert = 1
    cost_delete = 1
    cost_substitute = 1
    
    # Ambil tipe dan konten dari kedua node
    target_type = target_node_data.get('type', 'Unknown')
    other_type = other_node_data.get('type', 'Unknown')
    
    target_label = target_node_data.get('label', 'Unknown')
    other_label = other_node_data.get('label', 'Unknown')

    # Jika salah satu node hilang
    if not target_node_data or not other_node_data:
        cost = cost_insert
    # Jika tipe berbeda, maka butuh delete + insert
    elif target_type != other_type:
        cost = cost_delete + cost_insert  # Total cost = 2
    # Jika tipe sama tetapi label berbeda, hanya perlu subtitusi
    elif target_label != other_label:
        cost = cost_substitute
    # Jika sama persis, tidak ada cost
    else:
        cost = 0

    # Konversi cost ke similarity
    if cost == 0:
        similarity = 1.0  # 100% similarity
    elif cost == 1:
        similarity = 0.5  # 50% similarity
    else:
        similarity = 0.0  # 0% similarity

    print(f"Cost: {cost}, Structural Similarity: {similarity}")
    
    return similarity, cost


def detect_missing_nodes_by_count(graph):
    """
    Detects missing nodes in the graph based on their count.
    A node is considered missing if it does not appear at least twice in the graph.
    """
    node_counts = {}
    
    # Count occurrences of each node in edges (both source and target)
    for source, target in graph.edges():
        node_counts[source] = node_counts.get(source, 0) + 1
        node_counts[target] = node_counts.get(target, 0) + 1

    # Identify nodes with less than 2 occurrences
    missing_nodes = [node for node, count in node_counts.items() if count < 2 and node not in ("StartEvent", "EndEvent")]
    # print("node_counts:", node_counts)
    # print("Missing Node:", missing_nodes)
    return missing_nodes


def calculate_combined_similarity_with_ged(target_graph, target_node, other_graph, other_node, component):
    """
    Menghitung kemiripan kombinasi (semantic + structural) antar node.
    - **Semantic similarity** dihitung dengan cosine similarity.
    - **Structural similarity** dihitung dengan Graph Edit Distance (GED).
    """

    # Ambil data node
    target_node_data = target_node[1]
    other_node_data = other_node[1]

    # Hitung kemiripan semantic
    semantic_similarity = calculate_semantic_similarity(target_node_data, other_node_data, component)

    # Hitung kemiripan structural menggunakan GED
    structural_similarity, cost = calculate_structural_similarity(target_node_data, other_node_data)
    
    print(f"Semantic Similarity: {semantic_similarity}, Structural Similarity: {structural_similarity}")

    # Kombinasikan dengan bobot yang sama (50% semantic, 50% structural)
    return semantic_similarity, structural_similarity, cost


def compare_bpmn_with_missing_node_detection(target_data, other_data_list):
    """
    Membandingkan target graph node-by-node dengan graph lain,
    menggunakan GED Greedy untuk structural similarity dan semantic similarity,
    serta mendeteksi missing nodes langsung dari target graph.
    """
    target_graph = convert_to_interstructural_with_order(target_data)
    target_nodes = list(target_graph.nodes(data=True))
    
    best_graph = None
    best_graph_name = None
    best_similarity = 0
    best_semantic = 0
    best_structural = 0
    best_total_cost = 0
    best_missing_nodes = []
    best_cost = 0

    # Detect missing nodes from the target graph
    target_missing_nodes = detect_missing_nodes_by_count(target_graph)
    print("Target Missing Nodes:", target_missing_nodes)

    for other_data in other_data_list:
        current_missing_nodes = []
        print(f"\nComparing with: {other_data['file_name']}")
        other_graph = convert_to_interstructural_with_order(other_data)
        other_nodes = list(other_graph.nodes(data=True))

        print(f"{other_data['file_name']} Nodes:", list(other_graph.nodes()))

        total_semantic_similarity_graph = 0
        total_structural_similarity_graph = 0
        total_cost_graph = 0
        total_nodes_compared_graph = 0
        total_similarity = 0
        valid = True

        i, j = 0, 0
        while i < len(target_nodes) and j < len(other_nodes):
            target_nc = target_nodes[i]
            other_nc = other_nodes[j]

            component_type = 'activities' if target_nc[1].get('type') != 'Transition' else 'transitions'

            if target_nc[0] in target_missing_nodes:
                print(f"Missing node detected: {target_nc[0]} - Reason: Consecutive non-Transition nodes")

                match_found = False
                for k in range(j, len(other_nodes)):
                    other_nc_next = other_nodes[k]
                    semantic_similarity, structural_similarity, cost = calculate_combined_similarity_with_ged(
                        target_graph, target_nc, other_graph, other_nc_next, component_type
                    )
                    
                    total_cost_graph += cost

                    combined_similarity_next = 0.5 * semantic_similarity + 0.5 * structural_similarity

                    print(f"{target_nc[0]} vs {other_nc_next[0]}: {combined_similarity_next}")

                    if combined_similarity_next > 0.5:
                        print(f"Match {target_nc[0]} vs {other_nc_next[0]}: {combined_similarity_next}")
                        match_found = True
                        total_similarity += combined_similarity_next
                        total_nodes_compared_graph += 1

                        total_semantic_similarity_graph += semantic_similarity
                        total_structural_similarity_graph += structural_similarity

                        j = k  
                        break
                    else:
                        current_missing_nodes.append(other_nc_next[0])

                if not match_found:
                    print(f"Disqualifying graph: {other_data['file_name']} - Reason: Could not find match for missing node {target_nc[0]}")
                    valid = False
                    break
            
            else:
                semantic_similarity, structural_similarity, cost = calculate_combined_similarity_with_ged(
                    target_graph, target_nc, other_graph, other_nc, component_type
                )
                
                total_cost_graph += cost

                combined_similarity = 0.5 * semantic_similarity + 0.5 * structural_similarity

                print(f"Current: {target_nc[0]} vs {other_nc[0]} - Similarity: {combined_similarity}")

                if combined_similarity < 0.5:
                    print(f"Disqualifying graph: {other_data['file_name']} at node: {target_nc[0]} vs {other_nc[0]} - Similarity below threshold")
                    valid = False
                    break

                total_similarity += combined_similarity
                total_nodes_compared_graph += 1

                total_semantic_similarity_graph += semantic_similarity
                total_structural_similarity_graph += structural_similarity

            i += 1
            j += 1

        if valid and total_nodes_compared_graph > 0:
            avg_similarity = total_similarity / total_nodes_compared_graph
            avg_semantic_similarity_graph = (total_semantic_similarity_graph / total_nodes_compared_graph)
            avg_structural_similarity_graph = (total_structural_similarity_graph / total_nodes_compared_graph)

            print(f"\nGraph: {other_data['file_name']} - Average Combined Similarity: {avg_similarity:.2f}")
            print(f"Graph: {other_data['file_name']} - Total Semantic Similarity: {avg_semantic_similarity_graph}")
            print(f"Graph: {other_data['file_name']} - Total Structural Similarity: {avg_structural_similarity_graph}")
            print(f"Graph: {other_data['file_name']} - Total Cost: {total_cost_graph}")

            if avg_similarity > best_similarity:
                best_graph = other_graph
                best_graph_name = other_data.get('file_name', 'Unknown')
                best_similarity = avg_similarity
                best_semantic = avg_semantic_similarity_graph
                best_structural = avg_structural_similarity_graph
                best_missing_nodes = current_missing_nodes
                best_cost = total_cost_graph
                
                if j < len(other_nodes):
                    best_missing_nodes.extend(k[0] for k in other_nodes[j:])
    
    print("OEOE ", target_data)
    print(f"\nFinal Results: {target_data.get('file_name', 'Unknown')}")
    print("Best Graph:", best_graph_name)
    print("Best Similarity:", best_similarity)
    print("Best Semantic:", best_semantic)
    print("Best Structural:", best_structural)
    print("Best Cost:", best_cost)
    print(f"Target Missing Nodes: {target_missing_nodes}")
    print("Matching nodes:", best_missing_nodes)
    
    return best_graph, best_graph_name, target_graph



# Visualize graph with updated labels
def visualize_graph_with_labels(G, title="Graph Visualization", file_name="Graph.png"):
    # Update node labels to include "Start" and "End"
    # label_start_and_end_nodes(G)

    # Use the updated labels for visualization
    pos = nx.spring_layout(G)
    labels = nx.get_node_attributes(G, 'label')
    # Draw the graph with labels
    plt.figure(figsize=(12, 8))
    nx.draw(G, pos, with_labels=True, labels=labels, 
            node_color='lightblue', edge_color='black', node_size=1000, font_size=12, font_weight='bold')
    
    # Set title and adjust layout
    plt.title(title, fontsize=14)
    # plt.tight_layout()
    plt.savefig(file_name)
    plt.show()


if __name__ == "__main__":
    folder_path = 'Dataset repositori'
    target_file = 'XPDL Missing/BPM 1 EquipmentRecap.xpdl'

    # Parse target file
    target_data = parse_xpdl(target_file)
    target_data['file_name'] = target_file

    # Parse other files
    other_data_list = []
    for file_name in os.listdir(folder_path):
        if (file_name.endswith(".xpdl") or file_name.endswith(".xml"))  and file_name != os.path.basename(target_file):
            file_path = os.path.join(folder_path, file_name)
            parsed_data = parse_xpdl(file_path)
            parsed_data['file_name'] = file_name  # Add file name
            other_data_list.append(parsed_data)
    
    # Compare BPMNs
    best_graph, best_graph_name, target_graph = compare_bpmn_with_missing_node_detection(target_data, other_data_list)

    # Visualize the main graph
    visualize_graph_with_labels(target_graph, f"Graph Visualization of Target XPDL: {target_file}", f"Visual/Target.png")
    if best_graph:
        visualize_graph_with_labels(best_graph, f"Graph Visualization of Best Match: {best_graph_name}", f"Visual/Match.png")
# Out:
# ⚠️ Missing transitions detected! Attempting to reconstruct...
#   - input data to system (effd3951-491a-4de1-8cb7-986fb61d7ff7) is missing connections.
#   ✅ Reconstructed missing transition: input data to system → send to the store
#   - send to the store (165df246-4ec5-4af4-b8f5-5726c93fe9aa) is missing connections.
#   ✅ Reconstructed missing transition: send to the store → EndEvent
#   - EndEvent (61a9001b-9a33-4790-b582-1af76f631d94) is missing connections.
# Final Transitions: XPDL Missing/BPM 1 EquipmentRecap.xpdl [{'from': 'StartEvent', 'to': 'put a stamp on each tool'}, {'from': 'input data to system', 'to': 'send to the store'}, {'from': 'send to the store', 'to': 'EndEvent'}]
# Warning: Association source e7fc5953-e788-4e5b-80b8-d1629e69b68f not found in id_to_activity.
# Final Transitions: Dataset repositori\Add new item.xpdl [{'from': 'StartEvent', 'to': 'Asks to add new item'}, {'from': 'Asks to add new item', 'to': 'Displays form of  add new item'}, {'from': 'Displays form of  add new item', 'to': 'Enters a barcode'}, {'from': 'Enters a barcode', 'to': 'Queries for goods in the Goods database'}, {'from': 'Queries for goods in the Goods database', 'to': 'Displays the query results in the form '}, {'from': 'Displays the query results in the form ', 'to': 'Enters the selling price, purchase price, and initial stock'}, {'from': 'Enters the selling price, purchase price, and initial stock', 'to': 'c80e4e06-bdd7-4031-8ef6-8635e2aa206a'}, {'from': 'c80e4e06-bdd7-4031-8ef6-8635e2aa206a', 'to': 'Save the new item information'}, {'from': 'c80e4e06-bdd7-4031-8ef6-8635e2aa206a', 'to': '1b208ece-9b31-4f1b-973e-77f6ecb2a5bc'}, {'from': 'Save the new item information', 'to': '1b208ece-9b31-4f1b-973e-77f6ecb2a5bc'}, {'from': '1b208ece-9b31-4f1b-973e-77f6ecb2a5bc', 'to': 'EndEvent'}, {'from': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'to': 'data'}, {'from': 'Save the new item information', 'to': 'data'}]
# Warning: Association source 534cac9d-09d0-40e2-a2b1-00538ef0fefb not found in id_to_activity.
# Warning: Association source 163c3d6e-5114-4024-906b-3695f3fb2e47 not found in id_to_activity.
# Final Transitions: Dataset repositori\Add new member.xpdl [{'from': 'StartEvent', 'to': 'Asks for a member display'}, {'from': 'Asks for a member display', 'to': 'Reads the work unit '}, {'from': 'Reads the work unit ', 'to': 'Displays a member list form'}, {'from': 'Displays a member list form', 'to': 'Enters  wotk unit and name or ID member'}, {'from': 'Enters  wotk unit and name or ID member', 'to': 'queries to the member '}, {'from': 'queries to the member ', 'to': 'Display the main menu'}, {'from': 'Display the main menu', 'to': '37a4bac2-495d-4799-9b86-493284e1b9ab'}, {'from': '37a4bac2-495d-4799-9b86-493284e1b9ab', 'to': 'Adds a new member'}, {'from': 'Adds a new member', 'to': 'Displays the add member form'}, {'from': 'Displays the add member form', 'to': 'Enters new member data '}, {'from': 'Enters new member data ', 'to': 'Checks the validity of members'}, {'from': 'Checks the validity of members', 'to': '05dc3649-0424-4166-8128-f8be09f07dcd'}, {'from': '05dc3649-0424-4166-8128-f8be09f07dcd', 'to': '37a4bac2-495d-4799-9b86-493284e1b9ab'}, {'from': '05dc3649-0424-4166-8128-f8be09f07dcd', 'to': '7cf0a862-0c6f-4ca1-9368-e6815b2194b1'}, {'from': '7cf0a862-0c6f-4ca1-9368-e6815b2194b1', 'to': 'Stores new member data'}, {'from': '7cf0a862-0c6f-4ca1-9368-e6815b2194b1', 'to': '6e31f35d-972d-4e5f-ac20-fa495cc1a9f6'}, {'from': 'Stores new member data', 'to': '6e31f35d-972d-4e5f-ac20-fa495cc1a9f6'}, {'from': '6e31f35d-972d-4e5f-ac20-fa495cc1a9f6', 'to': 'EndEvent'}, {'from': '534cac9d-09d0-40e2-a2b1-00538ef0fefb', 'to': 'data'}, {'from': '163c3d6e-5114-4024-906b-3695f3fb2e47', 'to': 'data'}, {'from': 'Stores new member data', 'to': 'data'}]
# Final Transitions: Dataset repositori\Announcement of Audit Results.xpdl [{'from': 'StartEvent', 'to': 'Send Audit Results Report'}, {'from': 'Send Audit Results Report', 'to': 'Receive Audit Results Report'}, {'from': 'Receive Audit Results Report', 'to': 'Submitting Audit Result Report per unit'}, {'from': 'Submitting Audit Result Report per unit', 'to': 'Provide Recommendations for Performance Improvement'}, {'from': 'Provide Recommendations for Performance Improvement', 'to': 'Receive Audit Result Report Archives and Performance Improvement Recommendation'}, {'from': 'Receive Audit Result Report Archives and Performance Improvement Recommendation', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\book returning without fine.xpdl [{'from': 'StartEvent', 'to': 'Submit book + ID card + loan receipt'}, {'from': 'Submit book + ID card + loan receipt', 'to': 'Receive book + ID card + loan receipt'}, {'from': 'Receive book + ID card + loan receipt', 'to': 'Enter id number into ailis and match identity'}, {'from': 'Enter id number into ailis and match identity', 'to': 'Check loan status'}, {'from': 'Check loan status', 'to': 'Return book'}, {'from': 'Return book', 'to': 'record book returns'}, {'from': 'record book returns', 'to': 'Filing loan receipts'}, {'from': 'Filing loan receipts', 'to': 'Returning the book to the shelf'}, {'from': 'Returning the book to the shelf', 'to': 'Submit ID card'}, {'from': 'Submit ID card', 'to': 'Accept ID card'}, {'from': 'Accept ID card', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\book returning.xpdl [{'from': 'StartEvent', 'to': 'Submit book + ID card + loan receipt'}, {'from': 'Submit book + ID card + loan receipt', 'to': 'Receive book + ID card + loan receipt'}, {'from': 'Receive book + ID card + loan receipt', 'to': 'Enter id number into ailis and match identity'}, {'from': 'Enter id number into ailis and match identity', 'to': 'match identity'}, {'from': 'match identity', 'to': 'Check loan status'}, {'from': 'match identity', 'to': 'rejection'}, {'from': 'Check loan status', 'to': 'beyond the return date/no?'}, {'from': 'rejection', 'to': 'Refusing to return books'}, {'from': 'beyond the return date/no?', 'to': 'record book returns'}, {'from': 'beyond the return date/no?', 'to': 'Informing Siva of the amount of the fine'}, {'from': 'Refusing to return books', 'to': 'result'}, {'from': 'record book returns', 'to': 'conclusion'}, {'from': 'Informing Siva of the amount of the fine', 'to': 'Paying fine'}, {'from': 'result', 'to': 'final result'}, {'from': 'conclusion', 'to': 'Record book returns'}, {'from': 'Paying fine', 'to': 'Record payment of fines'}, {'from': 'final result', 'to': 'EndEvent'}, {'from': 'Record book returns', 'to': 'Filing loan receipts'}, {'from': 'Record payment of fines', 'to': 'Print out 2 copies of fines'}, {'from': 'Filing loan receipts', 'to': 'Returning the book to the shelf'}, {'from': 'Print out 2 copies of fines', 'to': 'Handing over the fine receipt for siva'}, {'from': 'Returning the book to the shelf', 'to': 'Submit ID card'}, {'from': 'Handing over the fine receipt for siva', 'to': 'Receipt of fines'}, {'from': 'Submit ID card', 'to': 'Accept ID card'}, {'from': 'Receipt of fines', 'to': 'conclusion'}, {'from': 'Accept ID card', 'to': 'result'}, {'from': 'Print out 2 copies of fines', 'to': 'Fine Receipt'}]
# Final Transitions: Dataset repositori\borrowing extensions.xpdl [{'from': 'StartEvent', 'to': 'Submit book + ID card'}, {'from': 'Submit book + ID card', 'to': 'Receive book + ID card'}, {'from': 'Receive book + ID card', 'to': 'Enter id number into ailis and match identity'}, {'from': 'Enter id number into ailis and match identity', 'to': 'e2ab8897-40c7-4fad-b727-17d5bdf4fba5'}, {'from': 'e2ab8897-40c7-4fad-b727-17d5bdf4fba5', 'to': 'Checking the parent number of the book whether the book is ordered'}, {'from': 'e2ab8897-40c7-4fad-b727-17d5bdf4fba5', 'to': 'Refusing to borrow books'}, {'from': 'Checking the parent number of the book whether the book is ordered', 'to': 'b142cef7-2afa-4bf4-ad1e-f5071bd0e7cb'}, {'from': 'Refusing to borrow books', 'to': 'Accept ID card'}, {'from': 'b142cef7-2afa-4bf4-ad1e-f5071bd0e7cb', 'to': 'Checking the return date'}, {'from': 'b142cef7-2afa-4bf4-ad1e-f5071bd0e7cb', 'to': 'Refuse extension'}, {'from': 'Accept ID card', 'to': 'result'}, {'from': 'Checking the return date', 'to': 'pass/no'}, {'from': 'Refuse extension', 'to': 'Accept ID card'}, {'from': 'result', 'to': 'final result'}, {'from': 'pass/no', 'to': 'receive borrowed book'}, {'from': 'pass/no', 'to': 'Informing Siva of the fine that must be paid'}, {'from': 'final result', 'to': 'EndEvent'}, {'from': 'receive borrowed book', 'to': '9e5bf854-ec81-49de-b01e-91a3c64ed99a'}, {'from': 'Informing Siva of the fine that must be paid', 'to': 'Paying fine'}, {'from': '9e5bf854-ec81-49de-b01e-91a3c64ed99a', 'to': 'Recording a borrowed receipts'}, {'from': 'Paying fine', 'to': 'Record payment of fines'}, {'from': 'Recording a borrowed receipts', 'to': 'Print duplicate borrowed receipts'}, {'from': 'Record payment of fines', 'to': 'Print out 2 copies of fines'}, {'from': 'Print duplicate borrowed receipts', 'to': 'Filing borrowed receipts'}, {'from': 'Print out 2 copies of fines', 'to': 'Handing over the fine receipt for siva'}, {'from': 'Filing borrowed receipts', 'to': 'Submit borrowed receipts'}, {'from': 'Handing over the fine receipt for siva', 'to': 'Receipt of fines'}, {'from': 'Submit borrowed receipts', 'to': 'Receive borrowed receipts'}, {'from': 'Receipt of fines', 'to': '9e5bf854-ec81-49de-b01e-91a3c64ed99a'}, {'from': 'Receive borrowed receipts', 'to': 'result'}, {'from': 'Print duplicate borrowed receipts', 'to': 'Loan Receipt'}]
# Final Transitions: Dataset repositori\borrowingbook.xpdl [{'from': 'StartEvent', 'to': 'fills in the guest book'}, {'from': 'fills in the guest book', 'to': 'Show member card'}, {'from': 'Show member card', 'to': 'Checks member card'}, {'from': 'Checks member card', 'to': 'member'}, {'from': 'member', 'to': 'allowed to enter the library'}, {'from': 'member', 'to': 'needs to register as a library member'}, {'from': 'allowed to enter the library', 'to': 'brings the books to the librarian desk who serves in the circulation sub section'}, {'from': 'needs to register as a library member', 'to': '7a0cee76-ce54-490a-a853-7890e14c14c3'}, {'from': 'brings the books to the librarian desk who serves in the circulation sub section', 'to': 'checks the books'}, {'from': '7a0cee76-ce54-490a-a853-7890e14c14c3', 'to': 'writes the logs in the borrowing check card'}, {'from': 'checks the books', 'to': '7a0cee76-ce54-490a-a853-7890e14c14c3'}, {'from': 'writes the logs in the borrowing check card', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\borrowingbookperiodends.xpdl [{'from': 'StartEvent', 'to': 'comes to the library'}, {'from': 'comes to the library', 'to': 'fills the guest book'}, {'from': 'fills the guest book', 'to': 'librarian checks the member card'}, {'from': 'librarian checks the member card', 'to': 'check the book'}, {'from': 'check the book', 'to': 'writes the log of book borrowing in the book borrowing check card.'}, {'from': 'writes the log of book borrowing in the book borrowing check card.', 'to': 'EndEvent'}]
# Warning: Association source 534cac9d-09d0-40e2-a2b1-00538ef0fefb not found in id_to_activity.
# Warning: Association source e7fc5953-e788-4e5b-80b8-d1629e69b68f not found in id_to_activity.
# Final Transitions: Dataset repositori\Change work unit.xpdl [{'from': 'StartEvent', 'to': 'Asks to move the member work unit'}, {'from': 'Asks to move the member work unit', 'to': 'Displays a form to move work units'}, {'from': 'Displays a form to move work units', 'to': '95886389-3a7a-49ce-97a0-9083d139f641'}, {'from': '95886389-3a7a-49ce-97a0-9083d139f641', 'to': 'Fills in information about the member '}, {'from': 'Fills in information about the member ', 'to': 'searches information of member '}, {'from': 'searches information of member ', 'to': 'c8cb5129-5c20-4f71-a3f3-a87f8b827264'}, {'from': 'c8cb5129-5c20-4f71-a3f3-a87f8b827264', 'to': 'Displays information  of member'}, {'from': 'c8cb5129-5c20-4f71-a3f3-a87f8b827264', 'to': '95886389-3a7a-49ce-97a0-9083d139f641'}, {'from': 'Displays information  of member', 'to': 'Enters a new work unit'}, {'from': 'Enters a new work unit', 'to': 'Verifies information of new work '}, {'from': 'Verifies information of new work ', 'to': 'afc65e35-2f6b-412d-8456-c1dccbf00e55'}, {'from': 'afc65e35-2f6b-412d-8456-c1dccbf00e55', 'to': 'Stores member information '}, {'from': 'afc65e35-2f6b-412d-8456-c1dccbf00e55', 'to': '0b129a82-edc8-4bbe-a4db-5843d21983c7'}, {'from': 'Stores member information ', 'to': '0b129a82-edc8-4bbe-a4db-5843d21983c7'}, {'from': '0b129a82-edc8-4bbe-a4db-5843d21983c7', 'to': 'EndEvent'}, {'from': '534cac9d-09d0-40e2-a2b1-00538ef0fefb', 'to': 'data'}, {'from': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'to': 'data'}, {'from': 'Stores member information ', 'to': 'data'}]
# Final Transitions: Dataset repositori\Closing Process.xpdl [{'from': 'StartEvent', 'to': 'Submit proof of last payment'}, {'from': 'Submit proof of last payment', 'to': 'Receive proof of last payment'}, {'from': 'Receive proof of last payment', 'to': 'Print the loan statement that is complete'}, {'from': 'Print the loan statement that is complete', 'to': 'Ask for signature of the statement'}, {'from': 'Ask for signature of the statement', 'to': 'Sign the payment certificate'}, {'from': 'Sign the payment certificate', 'to': 'Give the payment certificate'}, {'from': 'Give the payment certificate', 'to': 'Receive the payment certificate'}, {'from': 'Receive the payment certificate', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\collection_services_of_scientific_papers.xpdl [{'from': 'StartEvent', 'to': 'member submits the scientific paper'}, {'from': 'member submits the scientific paper', 'to': 'checks the completeness of scientific paper'}, {'from': 'checks the completeness of scientific paper', 'to': 'paper complete'}, {'from': 'paper complete', 'to': 'receives the scientific paper'}, {'from': 'paper complete', 'to': 'reject the scientific paper'}, {'from': 'receives the scientific paper', 'to': 'fills out the scientific paper submission form'}, {'from': 'reject the scientific paper', 'to': 'ffe0c0e9-a0e3-4c17-a4a5-78232688ca00'}, {'from': 'fills out the scientific paper submission form', 'to': 'processes the submitted scientific paper\xa0'}, {'from': 'ffe0c0e9-a0e3-4c17-a4a5-78232688ca00', 'to': 'EndEvent'}, {'from': 'processes the submitted scientific paper\xa0', 'to': 'gaves the letter of submitted scientific paper to the library member'}, {'from': 'gaves the letter of submitted scientific paper to the library member', 'to': 'categorizes the type of scientific paper'}, {'from': 'categorizes the type of scientific paper', 'to': 'puts the scientific paper in the cabinet'}, {'from': 'puts the scientific paper in the cabinet', 'to': 'archives the documents'}, {'from': 'archives the documents', 'to': 'ffe0c0e9-a0e3-4c17-a4a5-78232688ca00'}]
# Warning: Association source e682a3f7-68cb-4303-86d4-0043c6956ea0 not found in id_to_activity.
# Warning: Association source d87c8137-5ff1-4d93-9332-59cb7bb58344 not found in id_to_activity.
# Final Transitions: Dataset repositori\Corporate inpatient registration.xpdl [{'from': 'StartEvent', 'to': 'Wants to register Inpatient for corporate patients'}, {'from': 'Wants to register Inpatient for corporate patients', 'to': 'Displays an inpatient registration form'}, {'from': 'Displays an inpatient registration form', 'to': 'Enters the medical record ID'}, {'from': 'Enters the medical record ID', 'to': 'Reads the Patient database'}, {'from': 'Reads the Patient database', 'to': 'Displays  the query results '}, {'from': 'Displays  the query results ', 'to': "Includes information about the patient's handler"}, {'from': "Includes information about the patient's handler", 'to': 'Includes registration information'}, {'from': 'Includes registration information', 'to': '05603d03-8106-47d8-a069-8e37915278b5'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': 'Reads the Referral database'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5'}, {'from': 'Reads the Referral database', 'to': 'Displays a list of referrals'}, {'from': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5', 'to': 'Selects an emergency button'}, {'from': 'Displays a list of referrals', 'to': 'Selects the referral'}, {'from': 'Selects an emergency button', 'to': 'aa610af4-2005-4250-a0d8-78cf8c37adf2'}, {'from': 'Selects the referral', 'to': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5'}, {'from': 'aa610af4-2005-4250-a0d8-78cf8c37adf2', 'to': 'Runs the emergency form'}, {'from': 'aa610af4-2005-4250-a0d8-78cf8c37adf2', 'to': '4b0628d9-3043-40af-8c26-c8eeac9796ab'}, {'from': 'Runs the emergency form', 'to': '4b0628d9-3043-40af-8c26-c8eeac9796ab'}, {'from': '4b0628d9-3043-40af-8c26-c8eeac9796ab', 'to': 'Selects a register button'}, {'from': 'Selects a register button', 'to': '69ffaaeb-dc0b-47ab-a694-32e6b07fd010'}, {'from': '69ffaaeb-dc0b-47ab-a694-32e6b07fd010', 'to': 'Generates the hospitalization number'}, {'from': '69ffaaeb-dc0b-47ab-a694-32e6b07fd010', 'to': '13a7059c-94ce-4147-9fea-20a03be5baf0'}, {'from': 'Generates the hospitalization number', 'to': 'Saves the registration information'}, {'from': '13a7059c-94ce-4147-9fea-20a03be5baf0', 'to': 'EndEvent'}, {'from': 'Saves the registration information', 'to': 'Risplays the registration information '}, {'from': 'Risplays the registration information ', 'to': '13a7059c-94ce-4147-9fea-20a03be5baf0'}, {'from': 'e682a3f7-68cb-4303-86d4-0043c6956ea0', 'to': 'data'}, {'from': 'Saves the registration information', 'to': 'data'}, {'from': 'd87c8137-5ff1-4d93-9332-59cb7bb58344', 'to': 'data'}]
# Warning: Association source eaadbd60-2555-47df-a090-4f2c136a83ba not found in id_to_activity.
# Warning: Association source 3d9a2108-0d43-412e-a966-0d63e7639fa0 not found in id_to_activity.
# Warning: Association source d4da603f-9ff9-4416-a780-2f80753c7e58 not found in id_to_activity.
# Warning: Association source 2f8d5491-7e8b-40fd-bc01-bc030b7a54b8 not found in id_to_activity.
# Final Transitions: Dataset repositori\Corporate new patient registration.xpdl [{'from': 'StartEvent', 'to': 'Wants to register a new corporate patient'}, {'from': 'Wants to register a new corporate patient', 'to': 'Queries District, Subdistric, Village, and Referral'}, {'from': 'Queries District, Subdistric, Village, and Referral', 'to': 'Displays a registration form '}, {'from': 'Displays a registration form ', 'to': "Enters the patient's identity "}, {'from': "Enters the patient's identity ", 'to': "Enter the patient's address "}, {'from': "Enter the patient's address ", 'to': 'Enters company informationk 1'}, {'from': 'Enters company informationk 1', 'to': 'Selects the register button'}, {'from': 'Selects the register button', 'to': '6fe753e9-ea2f-4694-a19f-d7585b540d01'}, {'from': '6fe753e9-ea2f-4694-a19f-d7585b540d01', 'to': 'Saves the registration information '}, {'from': '6fe753e9-ea2f-4694-a19f-d7585b540d01', 'to': '0b5b77be-75b0-45a9-bd17-b1997420ce28'}, {'from': 'Saves the registration information ', 'to': 'displays the registration information to a table in the form'}, {'from': '0b5b77be-75b0-45a9-bd17-b1997420ce28', 'to': 'EndEvent'}, {'from': 'displays the registration information to a table in the form', 'to': '0b5b77be-75b0-45a9-bd17-b1997420ce28'}, {'from': 'Saves the registration information ', 'to': 'data'}, {'from': 'eaadbd60-2555-47df-a090-4f2c136a83ba', 'to': 'data'}, {'from': '3d9a2108-0d43-412e-a966-0d63e7639fa0', 'to': 'data'}, {'from': 'd4da603f-9ff9-4416-a780-2f80753c7e58', 'to': 'data'}, {'from': '2f8d5491-7e8b-40fd-bc01-bc030b7a54b8', 'to': 'data'}, {'from': 'Saves the registration information ', 'to': 'data'}]
# Final Transitions: Dataset repositori\Critics&SuggestionsManagement.xpdl [{'from': 'StartEvent', 'to': 'send criticism and suggestions'}, {'from': 'send criticism and suggestions', 'to': 'respond to criticism and suggestions'}, {'from': 'respond to criticism and suggestions', 'to': 'coordinate with other parties'}, {'from': 'coordinate with other parties', 'to': 'send the results of criticism and suggestions via online'}, {'from': 'send the results of criticism and suggestions via online', 'to': 'receive notifications'}, {'from': 'receive notifications', 'to': 'EndEvent'}]
# Warning: Association source e9823ddf-c2ea-442a-9799-d49404150f02 not found in id_to_activity.
# Final Transitions: Dataset repositori\Daily revenue report.xpdl [{'from': 'StartEvent', 'to': 'Wants to create a Daily revenue report'}, {'from': 'Wants to create a Daily revenue report', 'to': 'Displays the Daily revenue report form'}, {'from': 'Displays the Daily revenue report form', 'to': 'Enters the start date, end date, and category '}, {'from': 'Enters the start date, end date, and category ', 'to': 'Selects the search button'}, {'from': 'Selects the search button', 'to': 'c5ee00ff-cc1f-4267-9efc-8ea408868599'}, {'from': 'c5ee00ff-cc1f-4267-9efc-8ea408868599', 'to': 'Queries the Revenue database '}, {'from': 'c5ee00ff-cc1f-4267-9efc-8ea408868599', 'to': '6f3fadd9-7ee1-4626-be74-4ac3327fe518'}, {'from': 'Queries the Revenue database ', 'to': 'Displays the query result '}, {'from': '6f3fadd9-7ee1-4626-be74-4ac3327fe518', 'to': 'Select  a print  button'}, {'from': 'Displays the query result ', 'to': '6f3fadd9-7ee1-4626-be74-4ac3327fe518'}, {'from': 'Select  a print  button', 'to': 'ccb484c1-0a50-4c27-be4e-ac809400520e'}, {'from': 'ccb484c1-0a50-4c27-be4e-ac809400520e', 'to': 'Prints to printer'}, {'from': 'ccb484c1-0a50-4c27-be4e-ac809400520e', 'to': '7a3f28d2-8c48-4551-9672-ee6753bda510'}, {'from': 'ccb484c1-0a50-4c27-be4e-ac809400520e', 'to': 'Print to xcell file'}, {'from': 'Prints to printer', 'to': '7a3f28d2-8c48-4551-9672-ee6753bda510'}, {'from': '7a3f28d2-8c48-4551-9672-ee6753bda510', 'to': 'EndEvent'}, {'from': 'Print to xcell file', 'to': '7a3f28d2-8c48-4551-9672-ee6753bda510'}, {'from': 'e9823ddf-c2ea-442a-9799-d49404150f02', 'to': 'data'}]
# Final Transitions: Dataset repositori\Determination of Auditor.xpdl [{'from': 'StartEvent', 'to': 'Issue an Auditor Recommendation Letter and Visitation Schedule'}, {'from': 'Issue an Auditor Recommendation Letter and Visitation Schedule', 'to': 'Receive Recommendation Letter\xa0 & Visitation Schedule'}, {'from': 'Receive Recommendation Letter\xa0 & Visitation Schedule', 'to': "Making an Auditor's Decree Based on the Auditor's Recommendation Letter"}, {'from': "Making an Auditor's Decree Based on the Auditor's Recommendation Letter", 'to': "Sending Auditor's Decision Letter"}, {'from': "Sending Auditor's Decision Letter", 'to': 'Receive the decision Letter'}, {'from': 'Receive the decision Letter', 'to': 'EndEvent'}]
# Warning: Association source e7fc5953-e788-4e5b-80b8-d1629e69b68f not found in id_to_activity.
# Final Transitions: Dataset repositori\Display cash inflow.xpdl [{'from': 'StartEvent', 'to': 'Wants to display cash inflow'}, {'from': 'Wants to display cash inflow', 'to': 'Displays the cash inflow form'}, {'from': 'Displays the cash inflow form', 'to': 'Fills in the year and month '}, {'from': 'Fills in the year and month ', 'to': 'Queries about the cash inflow in the cash database'}, {'from': 'Queries about the cash inflow in the cash database', 'to': 'Displays the query result '}, {'from': 'Displays the query result ', 'to': 'bf8db104-94fe-43d9-b858-43e2e47663dd'}, {'from': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'to': 'Prints a report to the printer'}, {'from': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'to': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'}, {'from': 'Prints a report to the printer', 'to': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'}, {'from': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'to': 'EndEvent'}, {'from': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'to': 'data'}]
# Warning: Association source e7fc5953-e788-4e5b-80b8-d1629e69b68f not found in id_to_activity.
# Final Transitions: Dataset repositori\Display cash outflow.xpdl [{'from': 'StartEvent', 'to': 'Wants to display cash inflow'}, {'from': 'Wants to display cash inflow', 'to': 'Displays the cash inflow form'}, {'from': 'Displays the cash inflow form', 'to': 'Fills in the year and month '}, {'from': 'Fills in the year and month ', 'to': 'Queries about the cash inflow in the cash database'}, {'from': 'Queries about the cash inflow in the cash database', 'to': 'Displays the query result '}, {'from': 'Displays the query result ', 'to': 'bf8db104-94fe-43d9-b858-43e2e47663dd'}, {'from': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'to': 'Prints a report to the printer'}, {'from': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'to': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'}, {'from': 'Prints a report to the printer', 'to': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'}, {'from': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'to': 'EndEvent'}, {'from': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'to': 'data'}]
# Warning: Association source d3841eb4-74a0-4708-9a9f-5937533099d4 not found in id_to_activity.
# Warning: Association source 72dd12f5-fa38-4d24-8ccb-eaf123581305 not found in id_to_activity.
# Final Transitions: Dataset repositori\Display mandatory savings.xpdl [{'from': 'StartEvent', 'to': 'Asks to display mandatory savings'}, {'from': 'Asks to display mandatory savings', 'to': 'Displays the form of displaying mandatory savings'}, {'from': 'Displays the form of displaying mandatory savings', 'to': "Selects the unit work & 'show'"}, {'from': "Selects the unit work & 'show'", 'to': 'Reads the Mandatory Saving and Member databases'}, {'from': 'Reads the Mandatory Saving and Member databases', 'to': 'Displays a recap of mandatory saving '}, {'from': 'Displays a recap of mandatory saving ', 'to': '311c63a7-e2e7-4d8a-a167-caa97e254958'}, {'from': '311c63a7-e2e7-4d8a-a167-caa97e254958', 'to': 'Prints the recap to the printer'}, {'from': '311c63a7-e2e7-4d8a-a167-caa97e254958', 'to': '44bd7aea-3334-4b14-9a4b-918a6aad3d08'}, {'from': 'Prints the recap to the printer', 'to': '44bd7aea-3334-4b14-9a4b-918a6aad3d08'}, {'from': '44bd7aea-3334-4b14-9a4b-918a6aad3d08', 'to': 'Selects one of the members '}, {'from': 'Selects one of the members ', 'to': 'Displays member data of setting the initial balance'}, {'from': 'Displays member data of setting the initial balance', 'to': 'Fills in the initial balance setting'}, {'from': 'Fills in the initial balance setting', 'to': '845d250f-580e-45cc-8ef4-4d3be563c204'}, {'from': '845d250f-580e-45cc-8ef4-4d3be563c204', 'to': 'Saves new information'}, {'from': '845d250f-580e-45cc-8ef4-4d3be563c204', 'to': '0983acdb-0bf6-46dc-afc0-4bb2e38f873c'}, {'from': 'Saves new information', 'to': '0983acdb-0bf6-46dc-afc0-4bb2e38f873c'}, {'from': '0983acdb-0bf6-46dc-afc0-4bb2e38f873c', 'to': 'EndEvent'}, {'from': 'd3841eb4-74a0-4708-9a9f-5937533099d4', 'to': 'data'}, {'from': '72dd12f5-fa38-4d24-8ccb-eaf123581305', 'to': 'data'}, {'from': 'Saves new information', 'to': 'data'}]
# Warning: Association source 534cac9d-09d0-40e2-a2b1-00538ef0fefb not found in id_to_activity.
# Final Transitions: Dataset repositori\Display member list.xpdl [{'from': 'StartEvent', 'to': 'Asks for a member display'}, {'from': 'Asks for a member display', 'to': 'Displays a member list form'}, {'from': 'Displays a member list form', 'to': 'Enters  wotk unit and name or ID member'}, {'from': 'Enters  wotk unit and name or ID member', 'to': 'queries to the member '}, {'from': 'queries to the member ', 'to': 'Display the main menu'}, {'from': 'Display the main menu', 'to': '9232021e-38ce-44dc-8921-050492980ae3'}, {'from': '9232021e-38ce-44dc-8921-050492980ae3', 'to': 'Runs the update member form'}, {'from': '9232021e-38ce-44dc-8921-050492980ae3', 'to': 'Runs the switch work unit form'}, {'from': '9232021e-38ce-44dc-8921-050492980ae3', 'to': 'Runs the form of the work unit history'}, {'from': '9232021e-38ce-44dc-8921-050492980ae3', 'to': 'Runs the form of change status'}, {'from': '9232021e-38ce-44dc-8921-050492980ae3', 'to': 'Runs the form of the new member'}, {'from': '9232021e-38ce-44dc-8921-050492980ae3', 'to': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265'}, {'from': 'Runs the update member form', 'to': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265'}, {'from': 'Runs the switch work unit form', 'to': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265'}, {'from': 'Runs the form of the work unit history', 'to': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265'}, {'from': 'Runs the form of change status', 'to': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265'}, {'from': 'Runs the form of the new member', 'to': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265'}, {'from': 'a63de61f-f1d5-47e9-a8f3-3c253cb77265', 'to': 'EndEvent'}, {'from': '534cac9d-09d0-40e2-a2b1-00538ef0fefb', 'to': 'data'}]
# Warning: Association source e7fc5953-e788-4e5b-80b8-d1629e69b68f not found in id_to_activity.
# Warning: Association source d3841eb4-74a0-4708-9a9f-5937533099d4 not found in id_to_activity.
# Warning: Association source 7a66b251-6876-4334-bed5-97ff5eae552f not found in id_to_activity.
# Final Transitions: Dataset repositori\Displays the history of moving work units.xpdl [{'from': 'StartEvent', 'to': 'Asks to display the history of moving work units'}, {'from': 'Asks to display the history of moving work units', 'to': 'Displays to display the history of moving work units'}, {'from': 'Displays to display the history of moving work units', 'to': 'Enters the member ID'}, {'from': 'Enters the member ID', 'to': 'Reads the member database'}, {'from': 'Reads the member database', 'to': 'Display member information'}, {'from': 'Display member information', 'to': 'Reads the work unit database'}, {'from': 'Reads the work unit database', 'to': 'Display work unit  information'}, {'from': 'Display work unit  information', 'to': 'Reads mutation database'}, {'from': 'Reads mutation database', 'to': "Displays the member's mutation information"}, {'from': "Displays the member's mutation information", 'to': 'EndEvent'}, {'from': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'to': 'data'}, {'from': 'd3841eb4-74a0-4708-9a9f-5937533099d4', 'to': 'data'}, {'from': '7a66b251-6876-4334-bed5-97ff5eae552f', 'to': 'data'}]
# Final Transitions: Dataset repositori\Distribution of Questionnaires.xpdl [{'from': 'StartEvent', 'to': 'Develop a satisfaction survey questionnaire'}, {'from': 'Develop a satisfaction survey questionnaire', 'to': 'Distribute the Questionnaire List'}, {'from': 'Distribute the Questionnaire List', 'to': 'Receive a list of questionnaires'}, {'from': 'Receive a list of questionnaires', 'to': '13b74a7a-654c-4993-b5b0-48356fa29293'}, {'from': '13b74a7a-654c-4993-b5b0-48356fa29293', 'to': 'Fill out the Questionnaire List'}, {'from': '13b74a7a-654c-4993-b5b0-48356fa29293', 'to': 'Return the Questionnaire'}, {'from': 'Fill out the Questionnaire List', 'to': 'a0091724-ce9b-4846-9b0b-cc9071367f7b'}, {'from': 'Return the Questionnaire', 'to': 'a0091724-ce9b-4846-9b0b-cc9071367f7b'}, {'from': 'a0091724-ce9b-4846-9b0b-cc9071367f7b', 'to': 'Collecting questionnaires'}, {'from': 'Collecting questionnaires', 'to': 'Receive the results of the completed questionnaire'}, {'from': 'Receive the results of the completed questionnaire', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\document_review_of_librarian_promotion.xpdl [{'from': 'StartEvent', 'to': 'receives the document'}, {'from': 'receives the document', 'to': 'submits the promotion document to the librarian coordinator reviewers'}, {'from': 'submits the promotion document to the librarian coordinator reviewers', 'to': 'review the document'}, {'from': 'review the document', 'to': 'recom'}, {'from': 'recom', 'to': 'send recommendation'}, {'from': 'send recommendation', 'to': 'receive recommendation'}, {'from': 'receive recommendation', 'to': 'approve'}, {'from': 'approve', 'to': 'EndEvent'}]
# Warning: Association source e682a3f7-68cb-4303-86d4-0043c6956ea0 not found in id_to_activity.
# Final Transitions: Dataset repositori\Down payment.xpdl [{'from': 'StartEvent', 'to': 'Wants to make a Down Payment transaction'}, {'from': 'Wants to make a Down Payment transaction', 'to': 'Displays Down Payment transaction form'}, {'from': 'Displays Down Payment transaction form', 'to': 'bbcb1d0b-dfd5-4096-9ba9-da46d77fd192'}, {'from': 'bbcb1d0b-dfd5-4096-9ba9-da46d77fd192', 'to': 'Enters Down Payment information'}, {'from': 'Enters Down Payment information', 'to': 'Searches for patients by register number'}, {'from': 'Searches for patients by register number', 'to': '7a3f28d2-8c48-4551-9672-ee6753bda510'}, {'from': '7a3f28d2-8c48-4551-9672-ee6753bda510', 'to': 'Displays patient information'}, {'from': '7a3f28d2-8c48-4551-9672-ee6753bda510', 'to': '5d54bd1c-b17e-4a4d-8364-237334e4b181'}, {'from': 'Displays patient information', 'to': '5d54bd1c-b17e-4a4d-8364-237334e4b181'}, {'from': '5d54bd1c-b17e-4a4d-8364-237334e4b181', 'to': '6bc7314b-ee04-4f16-af27-1f79dcebf3d1'}, {'from': '6bc7314b-ee04-4f16-af27-1f79dcebf3d1', 'to': 'bbcb1d0b-dfd5-4096-9ba9-da46d77fd192'}, {'from': '6bc7314b-ee04-4f16-af27-1f79dcebf3d1', 'to': 'Selects a save button'}, {'from': 'Selects a save button', 'to': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5'}, {'from': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5', 'to': 'Saves the Down Payment information'}, {'from': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5', 'to': '05603d03-8106-47d8-a069-8e37915278b5'}, {'from': 'Saves the Down Payment information', 'to': '05603d03-8106-47d8-a069-8e37915278b5'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': 'EndEvent'}, {'from': 'e682a3f7-68cb-4303-86d4-0043c6956ea0', 'to': 'data'}]
# Warning: Association source 7deabe40-5075-452a-847d-7be2682c9e91 not found in id_to_activity.
# Final Transitions: Dataset repositori\Emergency room Triage.xpdl [{'from': 'StartEvent', 'to': 'Wants to create an Emergency room Triage'}, {'from': 'Wants to create an Emergency room Triage', 'to': 'Displays the Emergency room Triage form'}, {'from': 'Displays the Emergency room Triage form', 'to': 'Enters register number of a patient'}, {'from': 'Enters register number of a patient', 'to': 'Sreads the Registration database'}, {'from': 'Sreads the Registration database', 'to': '8a71f31d-70b3-48c5-bc2c-eea96af4d56f'}, {'from': '8a71f31d-70b3-48c5-bc2c-eea96af4d56f', 'to': 'Displays patient information '}, {'from': '8a71f31d-70b3-48c5-bc2c-eea96af4d56f', 'to': 'Displays the message "data not found".'}, {'from': 'Displays patient information ', 'to': '7bcfb632-b79c-4c0f-b3d7-4da10fd0b486'}, {'from': 'Displays the message "data not found".', 'to': '7bcfb632-b79c-4c0f-b3d7-4da10fd0b486'}, {'from': '7bcfb632-b79c-4c0f-b3d7-4da10fd0b486', 'to': 'Selects the condition button'}, {'from': 'Selects the condition button', 'to': 'c4d65e81-c03c-4448-b16e-30e66f1889ea'}, {'from': 'c4d65e81-c03c-4448-b16e-30e66f1889ea', 'to': 'Bad'}, {'from': 'c4d65e81-c03c-4448-b16e-30e66f1889ea', 'to': 'Bad not emerfency'}, {'from': 'c4d65e81-c03c-4448-b16e-30e66f1889ea', 'to': 'Emerfency'}, {'from': 'c4d65e81-c03c-4448-b16e-30e66f1889ea', 'to': 'Deceased'}, {'from': 'Bad', 'to': '6fe753e9-ea2f-4694-a19f-d7585b540d01'}, {'from': 'Bad not emerfency', 'to': '6fe753e9-ea2f-4694-a19f-d7585b540d01'}, {'from': 'Emerfency', 'to': '6fe753e9-ea2f-4694-a19f-d7585b540d01'}, {'from': 'Deceased', 'to': '6fe753e9-ea2f-4694-a19f-d7585b540d01'}, {'from': '6fe753e9-ea2f-4694-a19f-d7585b540d01', 'to': 'Selects the save button'}, {'from': 'Selects the save button', 'to': '0b5b77be-75b0-45a9-bd17-b1997420ce28'}, {'from': '0b5b77be-75b0-45a9-bd17-b1997420ce28', 'to': 'Saves the triages '}, {'from': '0b5b77be-75b0-45a9-bd17-b1997420ce28', 'to': '30480a4a-9208-4c99-a015-5b6c33e47dfd'}, {'from': 'Saves the triages ', 'to': '30480a4a-9208-4c99-a015-5b6c33e47dfd'}, {'from': '30480a4a-9208-4c99-a015-5b6c33e47dfd', 'to': 'EndEvent'}, {'from': '7deabe40-5075-452a-847d-7be2682c9e91', 'to': 'data'}, {'from': 'Saves the triages ', 'to': 'data'}, {'from': 'Saves the triages ', 'to': 'data'}]
# Final Transitions: Dataset repositori\EncodeTag.xpdl [{'from': 'StartEvent', 'to': 'open the RFID reader application'}, {'from': 'open the RFID reader application', 'to': 'input the parent number id into the rfid tag'}, {'from': 'input the parent number id into the rfid tag', 'to': 'save the master number into the RFID tag'}, {'from': 'save the master number into the RFID tag', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\exhibition_organized_by_the_library.xpdl [{'from': 'StartEvent', 'to': 'identifies the needs.'}, {'from': 'identifies the needs.', 'to': 'classified the needs'}, {'from': 'classified the needs', 'to': 'lists the prioritize the needs'}, {'from': 'lists the prioritize the needs', 'to': 'verified the specifications of the needs'}, {'from': 'verified the specifications of the needs', 'to': '77b8d9f6-964f-4087-be27-e25ea61a13db'}, {'from': '77b8d9f6-964f-4087-be27-e25ea61a13db', 'to': 'selects material'}, {'from': '77b8d9f6-964f-4087-be27-e25ea61a13db', 'to': 'determines design'}, {'from': '77b8d9f6-964f-4087-be27-e25ea61a13db', 'to': 'prepares promotion concept'}, {'from': '77b8d9f6-964f-4087-be27-e25ea61a13db', 'to': 'prepares support event'}, {'from': 'selects material', 'to': '3faae8fd-531a-4060-bdcc-105255ccbbef'}, {'from': 'determines design', 'to': '3faae8fd-531a-4060-bdcc-105255ccbbef'}, {'from': 'prepares promotion concept', 'to': '3faae8fd-531a-4060-bdcc-105255ccbbef'}, {'from': 'prepares support event', 'to': '3faae8fd-531a-4060-bdcc-105255ccbbef'}, {'from': '3faae8fd-531a-4060-bdcc-105255ccbbef', 'to': 'do the exhibition together with the team'}, {'from': 'do the exhibition together with the team', 'to': 'promotes the event'}, {'from': 'promotes the event', 'to': 'reports the event to the head of library'}, {'from': 'reports the event to the head of library', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\Extend Loan Application.xpdl [{'from': 'StartEvent', 'to': 'Complete the extend document loan application'}, {'from': 'Complete the extend document loan application', 'to': 'Give the extend document loan application'}, {'from': 'Give the extend document loan application', 'to': 'receive the extend ocument loan application'}, {'from': 'receive the extend ocument loan application', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\External Cooperation.xpdl [{'from': 'StartEvent', 'to': 'apply for cooperation (MoA)'}, {'from': 'apply for cooperation (MoA)', 'to': 'study collaboration'}, {'from': 'study collaboration', 'to': 'agree/not'}, {'from': 'agree/not', 'to': 'coordinate with stakeholders'}, {'from': 'agree/not', 'to': 'send a letter of rejection of cooperation'}, {'from': 'coordinate with stakeholders', 'to': 'carry out cooperation'}, {'from': 'send a letter of rejection of cooperation', 'to': 're-apply for cooperation'}, {'from': 'carry out cooperation', 'to': 'conclusion'}, {'from': 're-apply for cooperation', 'to': 'conclusion'}, {'from': 'conclusion', 'to': 'end process'}, {'from': 'end process', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\ExternalCooperation.xpdl [{'from': 'StartEvent', 'to': 'apply for cooperation (MoA)'}, {'from': 'apply for cooperation (MoA)', 'to': 'study collaboration'}, {'from': 'study collaboration', 'to': 'agree/not'}, {'from': 'agree/not', 'to': 'coordinate with stakeholders'}, {'from': 'agree/not', 'to': 'send a letter of rejection of cooperation'}, {'from': 'coordinate with stakeholders', 'to': 'carry out cooperation'}, {'from': 'send a letter of rejection of cooperation', 'to': 're-apply for cooperation'}, {'from': 'carry out cooperation', 'to': 'conclusion'}, {'from': 're-apply for cooperation', 'to': 'conclusion'}, {'from': 'conclusion', 'to': 'end process'}, {'from': 'end process', 'to': 'EndEvent'}]
# Final Transitions: Dataset repositori\Field Visit.xpdl [{'from': 'StartEvent', 'to': 'Conduct field visits'}, {'from': 'Conduct field visits', 'to': 'Accept field visits\n'}, {'from': 'Accept field visits\n', 'to': 'Provide the required data\n'}, {'from': 'Provide the required data\n', 'to': 'Create audit results reports'}, {'from': 'Create audit results reports', 'to': 'EndEvent'}, {'from': 'Create audit results reports', 'to': 'Audit Results Report'}]
# Warning: Association source e682a3f7-68cb-4303-86d4-0043c6956ea0 not found in id_to_activity.
# Warning: Association source d87c8137-5ff1-4d93-9332-59cb7bb58344 not found in id_to_activity.
# Final Transitions: Dataset repositori\General inpatient registration.xpdl [{'from': 'StartEvent', 'to': 'Wants to register Inpatient for general patients'}, {'from': 'Wants to register Inpatient for general patients', 'to': 'Displays an inpatient registration form'}, {'from': 'Displays an inpatient registration form', 'to': 'Enters the medical record ID'}, {'from': 'Enters the medical record ID', 'to': 'Reads the Patient database'}, {'from': 'Reads the Patient database', 'to': 'Displays  the query results '}, {'from': 'Displays  the query results ', 'to': "Includes information about the patient's handler"}, {'from': "Includes information about the patient's handler", 'to': 'Includes registration information'}, {'from': 'Includes registration information', 'to': '05603d03-8106-47d8-a069-8e37915278b5'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': 'Reads the Referral database'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5'}, {'from': 'Reads the Referral database', 'to': 'Displays a list of referrals'}, {'from': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5', 'to': 'Selects an emergency button'}, {'from': 'Displays a list of referrals', 'to': 'Selects the referral'}, {'from': 'Selects an emergency button', 'to': 'aa610af4-2005-4250-a0d8-78cf8c37adf2'}, {'from': 'Selects the referral', 'to': 'd92e9b2e-6bb6-4a70-b633-1a4bc7e585f5'}, {'from': 'aa610af4-2005-4250-a0d8-78cf8c37adf2', 'to': 'Runs the emergency form'}, {'from': 'aa610af4-2005-4250-a0d8-78cf8c37adf2', 'to': '4b0628d9-3043-40af-8c26-c8eeac9796ab'}, {'from': 'Runs the emergency form', 'to': '4b0628d9-3043-40af-8c26-c8eeac9796ab'}, {'from': '4b0628d9-3043-40af-8c26-c8eeac9796ab', 'to': 'Selects a register button'}, {'from': 'Selects a register button', 'to': '69ffaaeb-dc0b-47ab-a694-32e6b07fd010'}, {'from': '69ffaaeb-dc0b-47ab-a694-32e6b07fd010', 'to': 'Generates the hospitalization number'}, {'from': '69ffaaeb-dc0b-47ab-a694-32e6b07fd010', 'to': '13a7059c-94ce-4147-9fea-20a03be5baf0'}, {'from': 'Generates the hospitalization number', 'to': 'Saves the registration information'}, {'from': '13a7059c-94ce-4147-9fea-20a03be5baf0', 'to': 'EndEvent'}, {'from': 'Saves the registration information', 'to': 'Displays the registration information '}, {'from': 'Displays the registration information ', 'to': '13a7059c-94ce-4147-9fea-20a03be5baf0'}, {'from': 'e682a3f7-68cb-4303-86d4-0043c6956ea0', 'to': 'data'}, {'from': 'Saves the registration information', 'to': 'data'}, {'from': 'd87c8137-5ff1-4d93-9332-59cb7bb58344', 'to': 'data'}]
# Warning: Association source eaadbd60-2555-47df-a090-4f2c136a83ba not found in id_to_activity.
# Warning: Association source 3d9a2108-0d43-412e-a966-0d63e7639fa0 not found in id_to_activity.
# Warning: Association source d4da603f-9ff9-4416-a780-2f80753c7e58 not found in id_to_activity.
# Warning: Association source 2f8d5491-7e8b-40fd-bc01-bc030b7a54b8 not found in id_to_activity.
# Final Transitions: Dataset repositori\General new patient registration.xpdl [{'from': 'StartEvent', 'to': 'Wants to register a new general patient'}, {'from': 'Wants to register a new general patient', 'to': 'Queries District, Subdistric, Village, and Referral'}, {'from': 'Queries District, Subdistric, Village, and Referral', 'to': 'Displays a registration form '}, {'from': 'Displays a registration form ', 'to': "Enters the patient's identity "}, {'from': "Enters the patient's identity ", 'to': "Enter the patient's address "}, {'from': "Enter the patient's address ", 'to': 'Selects the register button'}, {'from': 'Selects the register button', 'to': '6fe753e9-ea2f-4694-a19f-d7585b540d01'}, {'from': '6fe753e9-ea2f-4694-a19f-d7585b540d01', 'to': 'Saves the registration information '}, {'from': '6fe753e9-ea2f-4694-a19f-d7585b540d01', 'to': '0b5b77be-75b0-45a9-bd17-b1997420ce28'}, {'from': 'Saves the registration information ', 'to': 'displays the registration information to a table in the form'}, {'from': '0b5b77be-75b0-45a9-bd17-b1997420ce28', 'to': 'EndEvent'}, {'from': 'displays the registration information to a table in the form', 'to': '0b5b77be-75b0-45a9-bd17-b1997420ce28'}, {'from': 'Saves the registration information ', 'to': 'data'}, {'from': 'eaadbd60-2555-47df-a090-4f2c136a83ba', 'to': 'data'}, {'from': '3d9a2108-0d43-412e-a966-0d63e7639fa0', 'to': 'data'}, {'from': 'd4da603f-9ff9-4416-a780-2f80753c7e58', 'to': 'data'}, {'from': '2f8d5491-7e8b-40fd-bc01-bc030b7a54b8', 'to': 'data'}, {'from': 'Saves the registration information ', 'to': 'data'}]
# Warning: Association source e682a3f7-68cb-4303-86d4-0043c6956ea0 not found in id_to_activity.
# Warning: Association source 46744b38-e52d-4231-a0f6-7b64cecdb6b9 not found in id_to_activity.
# Final Transitions: Dataset repositori\General patient cashier.xpdl [{'from': 'StartEvent', 'to': 'Wants to make a general patient payment '}, {'from': 'Wants to make a general patient payment ', 'to': 'Displays a general patient payment  form'}, {'from': 'Displays a general patient payment  form', 'to': 'Enter the medical record ID'}, {'from': 'Enter the medical record ID', 'to': 'Reads the Patient and Registration Database'}, {'from': 'Reads the Patient and Registration Database', 'to': 'Displays the query results '}, {'from': 'Displays the query results ', 'to': 'Chooses the type of payment '}, {'from': 'Chooses the type of payment ', 'to': 'Reads the Transaction Master database'}, {'from': 'Reads the Transaction Master database', 'to': '6bc7314b-ee04-4f16-af27-1f79dcebf3d1'}, {'from': '6bc7314b-ee04-4f16-af27-1f79dcebf3d1', 'to': 'Enters the transaction code, transaction type, quantity'}, {'from': 'Enters the transaction code, transaction type, quantity', 'to': 'Displays the price'}, {'from': 'Displays the price', 'to': 'Adds it to the list'}, {'from': 'Adds it to the list', 'to': 'Displays it to the table'}, {'from': 'Displays it to the table', 'to': 'Selects an add button'}, {'from': 'Selects an add button', 'to': '05603d03-8106-47d8-a069-8e37915278b5'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': 'Selects a save button'}, {'from': '05603d03-8106-47d8-a069-8e37915278b5', 'to': '6bc7314b-ee04-4f16-af27-1f79dcebf3d1'}, {'from': 'Selects a save button', 'to': '9cecd4c0-b94d-457c-99d3-52cc97ee020f'}, {'from': '9cecd4c0-b94d-457c-99d3-52cc97ee020f', 'to': 'Saves the Transaction'}, {'from': 'Saves the Transaction', 'to': 'Prints the transaction to the printer'}, {'from': 'Saves the Transaction', 'to': 'e06571e0-a23d-405d-9bde-427856a91d60'}, {'from': 'Prints the transaction to the printer', 'to': 'e06571e0-a23d-405d-9bde-427856a91d60'}, {'from': 'e06571e0-a23d-405d-9bde-427856a91d60', 'to': 'EndEvent'}, {'from': 'e682a3f7-68cb-4303-86d4-0043c6956ea0', 'to': 'data'}, {'from': '46744b38-e52d-4231-a0f6-7b64cecdb6b9', 'to': 'data'}, {'from': 'Saves the Transaction', 'to': 'data'}, {'from': 'Saves the Transaction', 'to': 'data'}]
# ⚠️ Missing transitions detected! Attempting to reconstruct...
#   - EndEvent (57fd3017-c97a-4038-94cd-26805f10a24a) is missing connections.
#   ✅ Reconstructed missing transition: final result → EndEvent
#   - final result (8cf90868-ee5a-483e-90be-ad0810080816) is missing connections.
# ...
# Current: Transition_send to the store_to_EndEvent vs Transition_receive list_to_determines the collection which is no longer needed - Similarity: 0.75
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.5, Structural Similarity: 0.5
# Current: EndEvent vs determines the collection which is no longer needed - Similarity: 0.5
#
# Graph: weeding_process.xpdl - Average Combined Similarity: 0.67
# Graph: weeding_process.xpdl - Total Semantic Similarity: 0.7693458375356799
# Graph: weeding_process.xpdl - Total Structural Similarity: 0.5625
# Graph: weeding_process.xpdl - Total Cost: 12
#
# Comparing with: Withdraw mandatory deposits.xpdl
# parsed_data['transitions'] [{'from': 'StartEvent', 'to': 'Asks to withdraw mandatory deposits'}, {'from': 'Asks to withdraw mandatory deposits', 'to': 'Displays a mandatory deposits '}, {'from': 'Displays a mandatory deposits ', 'to': 'Enters the ID or name of the member'}, {'from': 'Enters the ID or name of the member', 'to': 'Chooses to display it '}, {'from': 'Chooses to display it ', 'to': 'Queries the Member database'}, {'from': 'Queries the Member database', 'to': 'Displays list of  members '}, {'from': 'Displays list of  members ', 'to': 'Selects one of the members'}, {'from': 'Selects one of the members', 'to': 'Reads the information about the deposit '}, {'from': 'Reads the information about the deposit ', 'to': 'Displays the information about the member and the deposit'}, {'from': 'Displays the information about the member and the deposit', 'to': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'}, {'from': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'to': 'Prints a report to the printer'}, {'from': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'to': 'bf8db104-94fe-43d9-b858-43e2e47663dd'}, {'from': 'Prints a report to the printer', 'to': 'bf8db104-94fe-43d9-b858-43e2e47663dd'}, {'from': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'to': 'EndEvent'}, {'from': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'to': 'data'}, {'from': '34950903-0ee1-4661-a608-eea711066d21', 'to': 'data'}]
# source_id-> StartEvent ||| {'name': 'StartEvent', 'type': 'Unknown'}
# target_id-> Asks to withdraw mandatory deposits ||| {'name': 'Asks to withdraw mandatory deposits', 'type': 'Unknown'}
# source_id-> Asks to withdraw mandatory deposits ||| {'name': 'Asks to withdraw mandatory deposits', 'type': 'Unknown'}
# target_id-> Displays a mandatory deposits  ||| {'name': 'Displays a mandatory deposits ', 'type': 'Unknown'}
# source_id-> Displays a mandatory deposits  ||| {'name': 'Displays a mandatory deposits ', 'type': 'Unknown'}
# target_id-> Enters the ID or name of the member ||| {'name': 'Enters the ID or name of the member', 'type': 'Unknown'}
# source_id-> Enters the ID or name of the member ||| {'name': 'Enters the ID or name of the member', 'type': 'Unknown'}
# target_id-> Chooses to display it  ||| {'name': 'Chooses to display it ', 'type': 'Unknown'}
# source_id-> Chooses to display it  ||| {'name': 'Chooses to display it ', 'type': 'Unknown'}
# target_id-> Queries the Member database ||| {'name': 'Queries the Member database', 'type': 'Unknown'}
# source_id-> Queries the Member database ||| {'name': 'Queries the Member database', 'type': 'Unknown'}
# target_id-> Displays list of  members  ||| {'name': 'Displays list of  members ', 'type': 'Unknown'}
# source_id-> Displays list of  members  ||| {'name': 'Displays list of  members ', 'type': 'Unknown'}
# target_id-> Selects one of the members ||| {'name': 'Selects one of the members', 'type': 'Unknown'}
# source_id-> Selects one of the members ||| {'name': 'Selects one of the members', 'type': 'Unknown'}
# target_id-> Reads the information about the deposit  ||| {'name': 'Reads the information about the deposit ', 'type': 'Unknown'}
# source_id-> Reads the information about the deposit  ||| {'name': 'Reads the information about the deposit ', 'type': 'Unknown'}
# target_id-> Displays the information about the member and the deposit ||| {'name': 'Displays the information about the member and the deposit', 'type': 'Unknown'}
# source_id-> Displays the information about the member and the deposit ||| {'name': 'Displays the information about the member and the deposit', 'type': 'Unknown'}
# target_id-> e8510fe5-4429-4b46-8ca7-bd0ad5201531 ||| {'id': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'name': '', 'type': None, 'is_start_event': False, 'is_end_event': False, 'from': ['990bd9b1-8998-43c4-ac0e-4a52d5511157'], 'to': ['6e01f2e6-ef04-43e4-8794-2410499d25be', 'bf8db104-94fe-43d9-b858-43e2e47663dd'], 'data_objects': [{'id': '28dbc148-0458-4dde-ab8e-5b5008fbd53b', 'name': 'Unit work', 'type': 'DataStore'}, {'id': '58e7be80-97ad-4ac1-b864-fa01e40a59af', 'name': 'Member', 'type': 'DataStore'}, {'id': '8c1d9377-9ba0-4bd9-bdd3-9bf3bb957353', 'name': 'mandatory Savings', 'type': 'DataStore'}, {'id': '20a7ac2f-d358-4fb1-9747-ca3e2602a785', 'name': 'Deposit', 'type': 'DataStore'}]}
# source_id-> e8510fe5-4429-4b46-8ca7-bd0ad5201531 ||| {'id': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'name': 'None_e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'type': None, 'is_start_event': False, 'is_end_event': False, 'from': ['990bd9b1-8998-43c4-ac0e-4a52d5511157'], 'to': ['6e01f2e6-ef04-43e4-8794-2410499d25be', 'bf8db104-94fe-43d9-b858-43e2e47663dd'], 'data_objects': [{'id': '28dbc148-0458-4dde-ab8e-5b5008fbd53b', 'name': 'Unit work', 'type': 'DataStore'}, {'id': '58e7be80-97ad-4ac1-b864-fa01e40a59af', 'name': 'Member', 'type': 'DataStore'}, {'id': '8c1d9377-9ba0-4bd9-bdd3-9bf3bb957353', 'name': 'mandatory Savings', 'type': 'DataStore'}, {'id': '20a7ac2f-d358-4fb1-9747-ca3e2602a785', 'name': 'Deposit', 'type': 'DataStore'}]}
# target_id-> Prints a report to the printer ||| {'name': 'Prints a report to the printer', 'type': 'Unknown'}
# source_id-> e8510fe5-4429-4b46-8ca7-bd0ad5201531 ||| {'id': 'e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'name': 'None_e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'type': None, 'is_start_event': False, 'is_end_event': False, 'from': ['990bd9b1-8998-43c4-ac0e-4a52d5511157'], 'to': ['6e01f2e6-ef04-43e4-8794-2410499d25be', 'bf8db104-94fe-43d9-b858-43e2e47663dd'], 'data_objects': [{'id': '28dbc148-0458-4dde-ab8e-5b5008fbd53b', 'name': 'Unit work', 'type': 'DataStore'}, {'id': '58e7be80-97ad-4ac1-b864-fa01e40a59af', 'name': 'Member', 'type': 'DataStore'}, {'id': '8c1d9377-9ba0-4bd9-bdd3-9bf3bb957353', 'name': 'mandatory Savings', 'type': 'DataStore'}, {'id': '20a7ac2f-d358-4fb1-9747-ca3e2602a785', 'name': 'Deposit', 'type': 'DataStore'}]}
# target_id-> bf8db104-94fe-43d9-b858-43e2e47663dd ||| {'id': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'name': '', 'type': None, 'is_start_event': False, 'is_end_event': False, 'from': ['6e01f2e6-ef04-43e4-8794-2410499d25be', 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'], 'to': ['09171f7a-43da-4930-be39-5281a0e344d1'], 'data_objects': [{'id': '28dbc148-0458-4dde-ab8e-5b5008fbd53b', 'name': 'Unit work', 'type': 'DataStore'}, {'id': '58e7be80-97ad-4ac1-b864-fa01e40a59af', 'name': 'Member', 'type': 'DataStore'}, {'id': '8c1d9377-9ba0-4bd9-bdd3-9bf3bb957353', 'name': 'mandatory Savings', 'type': 'DataStore'}, {'id': '20a7ac2f-d358-4fb1-9747-ca3e2602a785', 'name': 'Deposit', 'type': 'DataStore'}]}
# source_id-> Prints a report to the printer ||| {'name': 'Prints a report to the printer', 'type': 'Unknown'}
# target_id-> bf8db104-94fe-43d9-b858-43e2e47663dd ||| {'id': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'name': 'None_bf8db104-94fe-43d9-b858-43e2e47663dd', 'type': None, 'is_start_event': False, 'is_end_event': False, 'from': ['6e01f2e6-ef04-43e4-8794-2410499d25be', 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'], 'to': ['09171f7a-43da-4930-be39-5281a0e344d1'], 'data_objects': [{'id': '28dbc148-0458-4dde-ab8e-5b5008fbd53b', 'name': 'Unit work', 'type': 'DataStore'}, {'id': '58e7be80-97ad-4ac1-b864-fa01e40a59af', 'name': 'Member', 'type': 'DataStore'}, {'id': '8c1d9377-9ba0-4bd9-bdd3-9bf3bb957353', 'name': 'mandatory Savings', 'type': 'DataStore'}, {'id': '20a7ac2f-d358-4fb1-9747-ca3e2602a785', 'name': 'Deposit', 'type': 'DataStore'}]}
# source_id-> bf8db104-94fe-43d9-b858-43e2e47663dd ||| {'id': 'bf8db104-94fe-43d9-b858-43e2e47663dd', 'name': 'None_bf8db104-94fe-43d9-b858-43e2e47663dd', 'type': None, 'is_start_event': False, 'is_end_event': False, 'from': ['6e01f2e6-ef04-43e4-8794-2410499d25be', 'e8510fe5-4429-4b46-8ca7-bd0ad5201531'], 'to': ['09171f7a-43da-4930-be39-5281a0e344d1'], 'data_objects': [{'id': '28dbc148-0458-4dde-ab8e-5b5008fbd53b', 'name': 'Unit work', 'type': 'DataStore'}, {'id': '58e7be80-97ad-4ac1-b864-fa01e40a59af', 'name': 'Member', 'type': 'DataStore'}, {'id': '8c1d9377-9ba0-4bd9-bdd3-9bf3bb957353', 'name': 'mandatory Savings', 'type': 'DataStore'}, {'id': '20a7ac2f-d358-4fb1-9747-ca3e2602a785', 'name': 'Deposit', 'type': 'DataStore'}]}
# target_id-> EndEvent ||| {'name': 'EndEvent', 'type': 'Unknown'}
# source_id-> e7fc5953-e788-4e5b-80b8-d1629e69b68f ||| {'name': 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'type': 'Unknown'}
# target_id-> data ||| {'name': 'data', 'type': 'Unknown'}
# source_id-> 34950903-0ee1-4661-a608-eea711066d21 ||| {'name': '34950903-0ee1-4661-a608-eea711066d21', 'type': 'Unknown'}
# target_id-> data ||| {'name': 'data', 'type': 'Unknown'}
# Withdraw mandatory deposits.xpdl Nodes: ['StartEvent', 'Transition_StartEvent_to_Asks to withdraw mandatory deposits', 'Asks to withdraw mandatory deposits', 'Transition_Asks to withdraw mandatory deposits_to_Displays a mandatory deposits ', 'Displays a mandatory deposits ', 'Transition_Displays a mandatory deposits _to_Enters the ID or name of the member', 'Enters the ID or name of the member', 'Transition_Enters the ID or name of the member_to_Chooses to display it ', 'Chooses to display it ', 'Transition_Chooses to display it _to_Queries the Member database', 'Queries the Member database', 'Transition_Queries the Member database_to_Displays list of  members ', 'Displays list of  members ', 'Transition_Displays list of  members _to_Selects one of the members', 'Selects one of the members', 'Transition_Selects one of the members_to_Reads the information about the deposit ', 'Reads the information about the deposit ', 'Transition_Reads the information about the deposit _to_Displays the information about the member and the deposit', 'Displays the information about the member and the deposit', 'Transition_Displays the information about the member and the deposit_to_None_e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'None_e8510fe5-4429-4b46-8ca7-bd0ad5201531', 'Transition_None_e8510fe5-4429-4b46-8ca7-bd0ad5201531_to_Prints a report to the printer', 'Prints a report to the printer', 'Transition_None_e8510fe5-4429-4b46-8ca7-bd0ad5201531_to_None_bf8db104-94fe-43d9-b858-43e2e47663dd', 'None_bf8db104-94fe-43d9-b858-43e2e47663dd', 'Transition_Prints a report to the printer_to_None_bf8db104-94fe-43d9-b858-43e2e47663dd', 'Transition_None_bf8db104-94fe-43d9-b858-43e2e47663dd_to_EndEvent', 'EndEvent', 'e7fc5953-e788-4e5b-80b8-d1629e69b68f', 'Transition_e7fc5953-e788-4e5b-80b8-d1629e69b68f_to_data', 'data', '34950903-0ee1-4661-a608-eea711066d21', 'Transition_34950903-0ee1-4661-a608-eea711066d21_to_data']
# Cost: 0, Structural Similarity: 1.0
# Semantic Similarity: 1.0, Structural Similarity: 1.0
# Current: StartEvent vs StartEvent - Similarity: 1.0
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 1.0, Structural Similarity: 0.5
# Current: Transition_StartEvent_to_put a stamp on each tool vs Transition_StartEvent_to_Asks to withdraw mandatory deposits - Similarity: 0.75
# Missing node detected: put a stamp on each tool - Reason: Consecutive non-Transition nodes
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.5, Structural Similarity: 0.5
# put a stamp on each tool vs Asks to withdraw mandatory deposits: 0.5
# Cost: 2, Structural Similarity: 0.0
# Semantic Similarity: 0.06454972243679029, Structural Similarity: 0.0
# put a stamp on each tool vs Transition_Asks to withdraw mandatory deposits_to_Displays a mandatory deposits : 0.032274861218395144
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.6020620726159658, Structural Similarity: 0.5
# put a stamp on each tool vs Displays a mandatory deposits : 0.5510310363079829
# Match put a stamp on each tool vs Displays a mandatory deposits : 0.5510310363079829
# Missing node detected: input data to system - Reason: Consecutive non-Transition nodes
# Cost: 2, Structural Similarity: 0.0
# Semantic Similarity: 0.0, Structural Similarity: 0.0
# input data to system vs Transition_Displays a mandatory deposits _to_Enters the ID or name of the member: 0.0
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.5, Structural Similarity: 0.5
# input data to system vs Enters the ID or name of the member: 0.5
# Cost: 2, Structural Similarity: 0.0
# Semantic Similarity: 0.06933752452815364, Structural Similarity: 0.0
# input data to system vs Transition_Enters the ID or name of the member_to_Chooses to display it : 0.03466876226407682
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.625, Structural Similarity: 0.5
# input data to system vs Chooses to display it : 0.5625
# Match input data to system vs Chooses to display it : 0.5625
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 1.0, Structural Similarity: 0.5
# Current: Transition_input data to system_to_send to the store vs Transition_Chooses to display it _to_Queries the Member database - Similarity: 0.75
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.625, Structural Similarity: 0.5
# Current: send to the store vs Queries the Member database - Similarity: 0.5625
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 1.0, Structural Similarity: 0.5
# Current: Transition_send to the store_to_EndEvent vs Transition_Queries the Member database_to_Displays list of  members  - Similarity: 0.75
# Cost: 1, Structural Similarity: 0.5
# Semantic Similarity: 0.5, Structural Similarity: 0.5
# Current: EndEvent vs Displays list of  members  - Similarity: 0.5
#
# Graph: Withdraw mandatory deposits.xpdl - Average Combined Similarity: 0.68
# Graph: Withdraw mandatory deposits.xpdl - Total Semantic Similarity: 0.7940077590769957
# Graph: Withdraw mandatory deposits.xpdl - Total Structural Similarity: 0.5625
# Graph: Withdraw mandatory deposits.xpdl - Total Cost: 15
# OEOE  {'pools': [{'name': 'Main Process'}, {'name': 'Equipment Recap'}], 'lanes': [{'name': 'Staff'}], 'activities': [{'id': '49ccb7d5-3d90-4a6f-886a-1171e1d05051', 'name': 'StartEvent', 'type': 'None', 'is_start_event': True, 'is_end_event': False, 'from': [], 'to': ['39183995-e98c-450d-82a6-e1b15bb4308d'], 'data_objects': []}, {'id': '39183995-e98c-450d-82a6-e1b15bb4308d', 'name': 'put a stamp on each tool', 'type': 'None', 'is_start_event': False, 'is_end_event': False, 'from': ['49ccb7d5-3d90-4a6f-886a-1171e1d05051'], 'to': [], 'data_objects': []}, {'id': 'effd3951-491a-4de1-8cb7-986fb61d7ff7', 'name': 'input data to system', 'type': 'None', 'is_start_event': False, 'is_end_event': False, 'from': [], 'to': ['165df246-4ec5-4af4-b8f5-5726c93fe9aa'], 'data_objects': []}, {'id': '165df246-4ec5-4af4-b8f5-5726c93fe9aa', 'name': 'send to the store', 'type': 'None', 'is_start_event': False, 'is_end_event': False, 'from': ['effd3951-491a-4de1-8cb7-986fb61d7ff7'], 'to': ['61a9001b-9a33-4790-b582-1af76f631d94'], 'data_objects': []}, {'id': '61a9001b-9a33-4790-b582-1af76f631d94', 'name': 'EndEvent', 'type': 'None', 'is_start_event': False, 'is_end_event': True, 'from': ['165df246-4ec5-4af4-b8f5-5726c93fe9aa'], 'to': [], 'data_objects': []}], 'transitions': [{'from': 'StartEvent', 'to': 'put a stamp on each tool'}, {'from': 'input data to system', 'to': 'send to the store'}, {'from': 'send to the store', 'to': 'EndEvent'}], 'associations': [], 'message_flows': [], 'file_name': 'XPDL Missing/BPM 1 EquipmentRecap.xpdl'}
#
# Final Results: XPDL Missing/BPM 1 EquipmentRecap.xpdl
# Best Graph: PeriodicIssue.xpdl
# Best Similarity: 0.7536257938682637
# Best Semantic: 0.8822515877365275
# Best Structural: 0.625
# Best Cost: 8
# Target Missing Nodes: ['put a stamp on each tool', 'input data to system']
# Matching nodes: ['Transition_give stamp_to_input bibliography at ailis']
